# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshi2908/subsetselection/blob/main/subsetsel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Problem Statement:

#Find all the subsets from a set of numbers whose sum is zero.
#Constraint: Subset size must be 5
#Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}
import random as r
S={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}
for i in range(1,1001):
 a= r.sample(S,5)
 if sum(a)==0:
    print(a)
 #else:
   # print(sum(a))
# Out:
# [2, 9, 3, -5, -9]
# [6, 7, 1, -2, -12]
# [-7, -5, 2, 3, 7]
# [9, -8, 6, -4, -3]
# [-4, 6, -7, 11, -6]
# [11, 1, -2, -6, -4]
# [11, 2, 7, -8, -12]
# [6, -3, -5, -7, 9]
# [-2, -8, 7, -3, 6]
# [1, -3, -5, 11, -4]
# [11, -6, 7, -4, -8]
# [-2, -3, -9, 11, 3]
# [-6, -9, -2, 11, 6]
# [-4, 9, 1, 6, -12]
# [11, -7, 2, -12, 6]
# [-7, 7, -4, 6, -2]
# [6, -3, 11, -5, -9]
# [6, -9, -7, 3, 7]
# [-4, 7, 9, -3, -9]
# [11, -4, 2, -2, -7]
# [9, 6, -8, -4, -3]
# [-7, 3, 6, -3, 1]
# [3, -12, 2, 6, 1]
# [11, -3, -9, -5, 6]
# [6, 11, -7, 2, -12]
# [3, -5, -2, -3, 7]
# [-2, 1, 2, 3, -4]
# [2, -6, -8, 9, 3]
# <ipython-input-6-01563fd210cd>:9: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   a= r.sample(S,5)

# %%
#Find all the subsets from a set of numbers whose sum is zero.
#Constraint: Subset size must be 3 to 6 only
#Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}
import random as r
S={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}
for i in range(1,1001):
  for j in range(3,7):
   a= r.sample(S,j)
   if sum(a)==0:
     print(a)
# Out:
# [-2, 11, -9]
# [6, 2, 1, -9]
# [7, -3, 11, -9, -6]
# [-4, -3, 11, 1, -7, 2]
# [7, -12, -4, 9]
# [9, 2, -5, -6]
# [1, -9, 7, 6, -5]
# [2, 1, -3]
# [-8, 3, -7, 11, 6, -5]
# [11, -8, 3, -6]
# [9, -3, 2, 6, -2, -12]
# [6, 9, -8, -7]
# [7, -5, -2]
# [2, -8, 7, -4, 3]
# [2, 6, -8]
# [-5, -2, 7]
# [-4, -5, 9]
# [-6, 11, -7, 2]
# [7, -6, -3, 9, 2, -9]
# [7, -3, -4]
# [-2, 11, -7, -5, 3]
# [-6, 9, 2, -2, -9, 6]
# [-8, 2, 6]
# [-8, 2, -5, 6, -4, 9]
# [-2, 7, -5]
# [6, -3, -4, -2, 3]
# [-7, 3, -12, 1, 6, 9]
# [-4, -8, 6, 7, -3, 2]
# [2, -5, -6, 9]
# [6, -2, -4]
# [-2, 11, -9]
# [11, -4, 9, 1, -8, -9]
# [1, -5, -12, 7, 3, 6]
# [-9, 6, 11, -7, 3, -4]
# [-12, 9, -7, 7, 3]
# [-7, 3, -2, 6]
# [-3, -4, 9, -2]
# [-3, 9, -7, 6, -5]
# [-5, -8, -3, 9, 6, 1]
# [-4, -5, 9]
# [2, -4, -5, -9, 9, 7]
# [7, -12, -4, 9]
# [2, -5, -2, -9, 3, 11]
# [7, -8, 2, 6, -4, -3]
# [6, 11, 7, -12, -8, -4]
# [6, -2, -4, 9, -9]
# [-5, -8, 7, 6]
# [-3, 7, -4]
# [2, 11, -3, -6, -4]
# [-6, 2, 6, -2]
# [-8, 6, 2, 7, -7]
# ...
